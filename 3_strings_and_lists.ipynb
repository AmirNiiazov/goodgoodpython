# %%
s1 = 'panda'

# %%
print(s1)
# Out:
# panda

# %%
s1 = '''Hello
sfsdkljs sdfsdfs
sdfskfjsdf sdf'''

# %%
print(s1)
# Out:
# Hello
# sfsdkljs sdfsdfs
# sdfskfjsdf sdf

# %%
s1
# Out:
# 'Hello\nsfsdkljs sdfsdfs\nsdfskfjsdf sdf'

# %%
a = ''

# %%
a = ' '

# %%
bool(a)
# Out:
# True

# %%
s1 = 'Я люблю'

# %%
s2 = 'язык python'

# %%
s1 + s2
# Out:
# 'Я люблюязык python'

# %%
print(s1 + '\t' + s2)
# Out:
# Я люблю	язык python

# %%
type()
# Out:
# str

# %%
str(56.4)
# Out:
# '56.4'

# %%
'ha' * 3
# Out:
# 'hahaha'

# %%
class My:
    def __init__(self, data):
        self.data = data

    def __len__(self):
        n = 0
        for _ in self.data:
            n += 1
        return n

# %%
len(My('sdf'))
# Out:
# 3

# %%
"кот" > "кит"
# Out:
# True

# %%
'abcd' > 'aaadfgadsfdsfdsf'
# Out:
# True

# %%
'abcd' > 'abcd_'
# Out:
# False

# %%
ord('В')
# Out:
# 1042

# %%
ord('Ё')
# Out:
# 1025

# %%
chr(1025)
# Out:
# 'Ё'

# %%
s1 = input()
s2 = input()
print(' '.join([s1, s2]))
# Out:
# hello python

# %%
s1, s2 = input().split()
print(2 * (s1 + ' '), 3 * (s2 + ' '), sep='')
# Out:
# h h f f f

# %%
a, b = input().split()
print("Переменная a = " + a + ", переменная b = " + b)
# Out:
# Переменная a = 4, переменная b = 5

# %%
x = input()
print("Строка: " + x + ". Длина: " + str(len(x)))

# %%
s1, s2 = input().split()
print(s1 in s2, s1 == s2, s1 > s2, s1 < s2)

# %%
l1, l2 = input().split()
print("Коды: " + l1 + " = " + str(ord(l1)) + ", " + l2 + " = " + str(ord(l2)))
